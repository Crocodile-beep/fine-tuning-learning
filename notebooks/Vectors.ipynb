# %%
# Монтируем Google Drive, если ещё не смонтирован
from google.colab import drive
drive.mount('/content/drive')

# Импортируем настройки с монтированием Drive
# %run "/content/drive/MyDrive/Colab Notebooks/setup.ipynb"
# Out:
# Mounted at /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# git version 2.34.1
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# filter.lfs.required=true
# filter.lfs.clean=git-lfs clean -- %f
# user.name=Crocodile-beep
# user.email=crying.crokodile12@gmail.com
# Cloning into 'fine-tuning-learning'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), 4.98 KiB | 4.98 MiB/s, done.
# /content/fine-tuning-learning
# setup.ipynb  Vectors.ipynb

# %%
import numpy as np
import matplotlib.pyplot as plt

cat_vector = np.array([5, 3])  # Вектор "кот"
house_vector = np.array([8, 6])  # Вектор "дом" — уют, размер
combined = np.add(cat_vector, house_vector)  # Сложение
print("Кот + Дом:", combined)  # Комбинирует кота и дом — уютный кот в доме

big_house = house_vector * 1.5  # Скалярное умножение
print("Большой дом:", big_house)  # Усиливает уют и размер — большой дом

dot_product = np.dot(cat_vector, house_vector)  # Дот-продукт
print("Похожесть кота и дома:", dot_product)  # Похожесть кота и дома — низкая, разные сущности

garden_vector = np.array([3, 7])  # Вектор "сад"
combined_garden = np.add(house_vector, garden_vector)
dot_garden = np.dot(house_vector, garden_vector)
print("Дом + Сад:", combined_garden)  # Сложение дома и сада
print("Похожесть дома и сада:", dot_garden)  # Умеренная похожесть (места)
# Out:
# Кот + Дом: [13  9]
# Большой дом: [12.  9.]
# Похожесть кота и дома: 58
# Дом + Сад: [11 13]
# Похожесть дома и сада: 66

# %%
from google.colab import userdata
git_token = userdata.get('GIT_TOKEN')

# Переходим в репо и синхронизируем с GitHub (merge по умолчанию)
# %cd /content/fine-tuning-learning
# !git pull --no-rebase  # Используем merge для разрешения конфликта

# Создаём папку notebooks, если её нет
# !mkdir -p notebooks

# Проверяем и копируем ноутбук
# !ls /content/drive/MyDrive/Colab\ Notebooks/  # Убеждаемся, что файл есть
# !cp /content/drive/MyDrive/Colab\ Notebooks/Vectors.ipynb notebooks/Vectors.ipynb

# Коммит и пуш
# !git add notebooks/Vectors.ipynb
# !git commit -m "Добавлен ноутбук для шага 1.1 с заданиями по векторам"
# !git push https://Crocodile-beep:{git_token}@github.com/Crocodile-beep/fine-tuning-learning.git
# Out:
# /content/fine-tuning-learning
# error: You have not concluded your merge (MERGE_HEAD exists).
# hint: Please, commit your changes before merging.
# fatal: Exiting because of unfinished merge.
# setup.ipynb  Vectors.ipynb
# [main b322633] Добавлен ноутбук для шага 1.1 с заданиями по векторам
# Enumerating objects: 15, done.
# Counting objects: 100% (15/15), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (10/10), done.
# Writing objects: 100% (12/12), 4.41 KiB | 4.41 MiB/s, done.
# Total 12 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), done.
# To https://github.com/Crocodile-beep/fine-tuning-learning.git
#    0d233c5..b322633  main -> main
